# %% [markdown]
# # Import Package

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from jcopml.pipeline import num_pipe, cat_pipe
from jcopml.feature_importance import mean_score_decrease

# %% [markdown]
# # Import Data

# %%
df = pd.read_csv("dataset.csv")
df.head()
# Out:
#       tanggal           wilayah      waktu         cuaca kelembaban_persen  \
# 0  2018-12-31  Kepulauan Seribu      Siang   Hujan Lokal           70 - 90
# 1  2018-12-31  Kepulauan Seribu       Pagi   Hujan Lokal           70 - 90
# 2  2018-12-31  Kepulauan Seribu      Malam   Hujan Lokal           70 - 90
# 3  2018-12-31  Kepulauan Seribu  Dini Hari  Hujan Ringan           70 - 90
# 4  2018-12-31     Jakarta Utara      Siang   Hujan Lokal           70 - 90
#
#   suhu_derajat_celcius
# 0              24 - 32
# 1              24 - 32
# 2              24 - 32
# 3              24 - 32
# 4              24 - 32

# %% [markdown]
# # Praprocessing

# %% [markdown]
# ### Jumlah Baris dan Kolom

# %%
df.shape
# Out:
# (8535, 6)

# %% [markdown]
# ### Melihat Missing Value

# %%
df.isnull().sum()
# Out:
# tanggal                 135
# wilayah                 135
# waktu                   135
# cuaca                   135
# kelembaban_persen       135
# suhu_derajat_celcius    135
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# tanggal                 0
# wilayah                 0
# waktu                   0
# cuaca                   0
# kelembaban_persen       0
# suhu_derajat_celcius    0
# dtype: int64

# %% [markdown]
# ### Melihat Kembali Jumlah Baris dan Kolom

# %%
df.shape
# Out:
# (8400, 6)

# %% [markdown]
# ### Mengubah value dari kolom Cuaca

# %%
df["cuaca"].unique()
# Out:
# array(['Hujan Lokal', 'Hujan Ringan', 'Berawan', 'Cerah Berawan', 'Cerah',
#        'Berawan Tebal', 'Hujan Sedang', 'Cerah Berawn', 'Cerang Berawan',
#        'Beawan', 'Berawan ', 'Hujan Petir', 'Hujan Lokal ',
#        'Cerah Berawan ', 'Cerah ', 'Cerah Berawah', 'Cerah  ', ' Berawan',
#        'Hujan', 'Hujan Petir ', 'Hujan Sedang ', 'Cerah berawan',
#        'Hujan Ringanl', 'Berawa', 'Hujang Sedang', 'Hujan Loka',
#        'Hujan Ringan '], dtype=object)

# %% [markdown]
# ### Menggunakan Regex untuk mengelompokkan jenis Cuaca

# %%
import re

def cuaca(x):
  if (re.findall("Cerah", x)):
    return 'Cerah'
  elif (re.findall("Hujan", x)):
    return 'Hujan'
  elif (re.findall("Berawan", x)):
    return 'Berawan'
  else:
    return 'Tidak Teridentifikasi'

df["cuaca"] = df['cuaca'].apply(cuaca)
df["cuaca"].value_counts()
# Out:
# Cerah                    3796
# Berawan                  2896
# Hujan                    1706
# Tidak Teridentifikasi       2
# Name: cuaca, dtype: int64

# %%
df.waktu.value_counts()
# Out:
# Siang        1758
# Pagi         1758
# Malam        1758
# Dini Hari    1758
# siang         342
# pagi          342
# malam         342
# dini hari     342
# Name: waktu, dtype: int64

# %%
import re

def cuaca(x):
  if (re.findall("dini hari", x)):
    return 'Dini Hari'
  elif (re.findall("siang", x)):
    return 'Siang'
  elif (re.findall("pagi", x)):
    return 'Pagi'
  elif (re.findall("malam", x)):
    return 'Malam'
  else:
    return x

df["waktu"] = df['waktu'].apply(cuaca)
df["waktu"].value_counts()
# Out:
# Siang        2100
# Pagi         2100
# Malam        2100
# Dini Hari    2100
# Name: waktu, dtype: int64

# %% [markdown]
# ### Drop Data

# %%
df[df["cuaca"] == "Tidak Teridentifikasi"].index
# Out:
# Int64Index([358, 7011], dtype='int64')

# %%
df.drop(df[df["cuaca"] == "Tidak Teridentifikasi"].index, inplace=True)
df["cuaca"].unique()
# Out:
# array(['Hujan', 'Berawan', 'Cerah'], dtype=object)

# %% [markdown]
# Split Data Kelembaban menjadi Kelembapan Minimal dan Maximal

# %%
df["kelembapan_min"] = df['kelembaban_persen'].apply(lambda x: x.split("-")[0])
df["kelembapan_min"] = [x.strip(' ') for x in df["kelembapan_min"]]

df["kelembapan_max"] = df['kelembaban_persen'].apply(lambda x: x.split("-")[1])
df["kelembapan_max"] = [x.strip(' ') for x in df["kelembapan_max"]]

df.head()
# Out:
#       tanggal           wilayah      waktu  cuaca kelembaban_persen  \
# 0  2018-12-31  Kepulauan Seribu      Siang  Hujan           70 - 90
# 1  2018-12-31  Kepulauan Seribu       Pagi  Hujan           70 - 90
# 2  2018-12-31  Kepulauan Seribu      Malam  Hujan           70 - 90
# 3  2018-12-31  Kepulauan Seribu  Dini Hari  Hujan           70 - 90
# 4  2018-12-31     Jakarta Utara      Siang  Hujan           70 - 90
#
#   suhu_derajat_celcius kelembapan_min kelembapan_max
# 0              24 - 32             70             90
# 1              24 - 32             70             90
# 2              24 - 32             70             90
# 3              24 - 32             70             90
# 4              24 - 32             70             90

# %%
df["suhu_min"] = df.suhu_derajat_celcius.apply(lambda x: x.split("-")[0])
df["suhu_min"] = [x.strip(' ') for x in df["suhu_min"]]

df["suhu_max"] = df.suhu_derajat_celcius.apply(lambda x: x.split("-")[1])
df["suhu_max"] = [x.strip(' ') for x in df["suhu_max"]]

df.head()
# Out:
#       tanggal           wilayah      waktu  cuaca kelembaban_persen  \
# 0  2018-12-31  Kepulauan Seribu      Siang  Hujan           70 - 90
# 1  2018-12-31  Kepulauan Seribu       Pagi  Hujan           70 - 90
# 2  2018-12-31  Kepulauan Seribu      Malam  Hujan           70 - 90
# 3  2018-12-31  Kepulauan Seribu  Dini Hari  Hujan           70 - 90
# 4  2018-12-31     Jakarta Utara      Siang  Hujan           70 - 90
#
#   suhu_derajat_celcius kelembapan_min kelembapan_max suhu_min suhu_max
# 0              24 - 32             70             90       24       32
# 1              24 - 32             70             90       24       32
# 2              24 - 32             70             90       24       32
# 3              24 - 32             70             90       24       32
# 4              24 - 32             70             90       24       32

# %% [markdown]
# Melihat Masing Masing Data dari Suhu

# %%
print('Suhu Min\n', df['suhu_min'].value_counts(), '\n')
print('Suhu Max\n', df['suhu_max'].value_counts(), '\n')
# Out:
# Suhu Min
#  24    4102
# 23    3072
# 25     576
# 22     552
# 21      48
# 20      24
# 26      24
# Name: suhu_min, dtype: int64
#
# Suhu Max
#  33    3431
# 32    1991
# 34    1440
# 31     696
# 30     360
# 35     288
# 29     120
# 28      72
# Name: suhu_max, dtype: int64

# %% [markdown]
# Melihat Masing Masing Data dari Kelembapan

# %%
print('Kelembapan Min\n', df['kelembapan_min'].value_counts(), '\n\n')
print('Kelembapan Min\n', df['kelembapan_max'].value_counts(), '\n')
# Out:
# Kelembapan Min
#  70    1727
# 55    1296
# 65    1272
# 60    1224
# 75     839
# 45     624
# 50     600
# 80     480
# 40     192
# 35      96
# 85      48
# Name: kelembapan_min, dtype: int64
#
#
# Kelembapan Min
#  95     3264
# 90     2375
# 85     1128
# 100    1031
# 80      504
# 75       96
# Name: kelembapan_max, dtype: int64

# %% [markdown]
# # Tahap Praprocessing 2

# %%
df.head()
# Out:
#       tanggal           wilayah      waktu  cuaca kelembaban_persen  \
# 0  2018-12-31  Kepulauan Seribu      Siang  Hujan           70 - 90
# 1  2018-12-31  Kepulauan Seribu       Pagi  Hujan           70 - 90
# 2  2018-12-31  Kepulauan Seribu      Malam  Hujan           70 - 90
# 3  2018-12-31  Kepulauan Seribu  Dini Hari  Hujan           70 - 90
# 4  2018-12-31     Jakarta Utara      Siang  Hujan           70 - 90
#
#   suhu_derajat_celcius kelembapan_min kelembapan_max suhu_min suhu_max
# 0              24 - 32             70             90       24       32
# 1              24 - 32             70             90       24       32
# 2              24 - 32             70             90       24       32
# 3              24 - 32             70             90       24       32
# 4              24 - 32             70             90       24       32

# %% [markdown]
# ### Drop Kolom

# %%
df.drop(columns=["kelembaban_persen", "suhu_derajat_celcius", "tanggal"], inplace=True)

# %%
df.wilayah.value_counts()
# Out:
# Jakarta Utara       1400
# Jakarta Timur       1400
# Jakarta Selatan     1400
# Jakarta Pusat       1400
# Kepulauan Seribu    1399
# Jakarta Barat       1399
# Name: wilayah, dtype: int64

# %% [markdown]
# ### Mengubah Tipe Data

# %%
df.dtypes
# Out:
# wilayah           object
# waktu             object
# cuaca             object
# kelembapan_min    object
# kelembapan_max    object
# suhu_min          object
# suhu_max          object
# dtype: object

# %%
df["kelembapan_min"] = df.kelembapan_min.astype(int)
df["kelembapan_max"] = df.kelembapan_max.astype(int)
df["suhu_min"] = df.suhu_min.astype(int)
df["suhu_max"] = df.suhu_max.astype(int)
df.dtypes
# Out:
# wilayah           object
# waktu             object
# cuaca             object
# kelembapan_min     int32
# kelembapan_max     int32
# suhu_min           int32
# suhu_max           int32
# dtype: object

# %% [markdown]
# # Visualisasi Data

# %%
sns.pairplot(df, hue="cuaca", corner=True)

# %% [markdown]
# # Target Encoding

# %%
replacement_mapping_dict = {
    "Cerah": 0,
    "Berawan": 1,
    "Hujan": 2,
}
df["cuaca"].replace(replacement_mapping_dict, inplace=True)

# %%
df["kelebapan_rata-rata"] = (df["kelembapan_min"] + df["kelembapan_max"]) / 2
df["suhu_rata-rata"] = (df["suhu_min"] + df["suhu_max"]) / 2

# %%
df.head()
# Out:
#             wilayah      waktu  cuaca  kelembapan_min  kelembapan_max  \
# 0  Kepulauan Seribu      Siang      2              70              90
# 1  Kepulauan Seribu       Pagi      2              70              90
# 2  Kepulauan Seribu      Malam      2              70              90
# 3  Kepulauan Seribu  Dini Hari      2              70              90
# 4     Jakarta Utara      Siang      2              70              90
#
#    suhu_min  suhu_max  kelebapan_rata-rata  suhu_rata-rata
# 0        24        32                 80.0            28.0
# 1        24        32                 80.0            28.0
# 2        24        32                 80.0            28.0
# 3        24        32                 80.0            28.0
# 4        24        32                 80.0            28.0

# %%
sns.pairplot(df, hue="cuaca", corner=True, palette="viridis")

# %% [markdown]
# # Splitting Data

# %%
X = df.drop(columns=["cuaca"])
y = df["cuaca"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((6718, 8), (1680, 8), (6718,), (1680,))

# %% [markdown]
# # Tahap Preprocessing 3

# %%
X_train.head()
# Out:
#               wilayah      waktu  kelembapan_min  kelembapan_max  suhu_min  \
# 1768    Jakarta Pusat      Siang              60              90        24
# 6034    Jakarta Timur      Malam              75              95        24
# 2491    Jakarta Pusat  Dini Hari              40              85        24
# 6349  Jakarta Selatan       Pagi              70              95        23
# 3486    Jakarta Utara      Malam              45              75        22
#
#       suhu_max  kelebapan_rata-rata  suhu_rata-rata
# 1768        34                 75.0            29.0
# 6034        34                 85.0            29.0
# 2491        34                 62.5            29.0
# 6349        33                 82.5            28.0
# 3486        32                 60.0            27.0

# %% [markdown]
# ### Dummies Encoding

# %%
X_train = pd.get_dummies(X_train, columns=["waktu", "wilayah"])
X_test = pd.get_dummies(X_test, columns=["waktu", "wilayah"])

# %%
X_train.head()
# Out:
#       kelembapan_min  kelembapan_max  suhu_min  suhu_max  kelebapan_rata-rata  \
# 1768              60              90        24        34                 75.0
# 6034              75              95        24        34                 85.0
# 2491              40              85        24        34                 62.5
# 6349              70              95        23        33                 82.5
# 3486              45              75        22        32                 60.0
#
#       suhu_rata-rata  waktu_Dini Hari  waktu_Malam  waktu_Pagi  waktu_Siang  \
# 1768            29.0                0            0           0            1
# 6034            29.0                0            1           0            0
# 2491            29.0                1            0           0            0
# 6349            28.0                0            0           1            0
# 3486            27.0                0            1           0            0
#
#       wilayah_Jakarta Barat  wilayah_Jakarta Pusat  wilayah_Jakarta Selatan  \
# 1768                      0                      1                        0
# 6034                      0                      0                        0
# 2491                      0                      1                        0
# 6349                      0                      0                        1
# 3486                      0                      0                        0
#
#       wilayah_Jakarta Timur  wilayah_Jakarta Utara  wilayah_Kepulauan Seribu
# 1768                      0                      0                         0
# 6034                      1                      0                         0
# 2491                      0                      0                         0
# 6349                      0                      0                         0
# 3486                      0                      1                         0

# %%
X_test.head()
# Out:
#       kelembapan_min  kelembapan_max  suhu_min  suhu_max  kelebapan_rata-rata  \
# 7548              70              90        24        31                 80.0
# 2230              45              90        24        34                 67.5
# 3589              55              85        23        33                 70.0
# 2520              50              90        23        34                 70.0
# 5419              55              90        24        33                 72.5
#
#       suhu_rata-rata  waktu_Dini Hari  waktu_Malam  waktu_Pagi  waktu_Siang  \
# 7548            27.5                0            0           0            1
# 2230            29.0                0            1           0            0
# 3589            28.0                0            0           1            0
# 2520            28.5                0            0           0            1
# 5419            28.5                1            0           0            0
#
#       wilayah_Jakarta Barat  wilayah_Jakarta Pusat  wilayah_Jakarta Selatan  \
# 7548                      0                      0                        1
# 2230                      1                      0                        0
# 3589                      0                      0                        1
# 2520                      0                      0                        0
# 5419                      0                      1                        0
#
#       wilayah_Jakarta Timur  wilayah_Jakarta Utara  wilayah_Kepulauan Seribu
# 7548                      0                      0                         0
# 2230                      0                      0                         0
# 3589                      0                      0                         0
# 2520                      0                      0                         1
# 5419                      0                      0                         0

# %% [markdown]
# # Fitting Data

# %% [markdown]
# ### Random Forest

# %%
from jcopml.tuning import grid_search_params as gsp
gsp.rf_params

paramater = {
    'n_estimators': [100, 150, 200],
    'max_depth': [20, 50, 80],
    'max_features': [0.3, 0.6, 0.8],
    'min_samples_leaf': [1, 5, 10]
}

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

RF = RandomForestClassifier(n_jobs=-1, random_state=42)

model = GridSearchCV(RF, paramater, cv=3, n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

print(model.best_params_)
# Out:
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# {'max_depth': 50, 'max_features': 0.6, 'min_samples_leaf': 5, 'n_estimators': 200}

# %%
from sklearn.metrics import confusion_matrix, classification_report

y_pred = model.predict(X_test)
y_pred_train = model.predict(X_train)

print(confusion_matrix(y_test, y_pred), "\n")
print(classification_report(y_train, y_pred_train), "\n")
print(classification_report(y_test, y_pred))
# Out:
# [[595 122  43]
#  [160 343  76]
#  [ 43  92 206]]
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82      3036
#            1       0.71      0.69      0.70      2317
#            2       0.75      0.71      0.73      1365
#
#     accuracy                           0.76      6718
#    macro avg       0.75      0.74      0.75      6718
# weighted avg       0.76      0.76      0.76      6718
#
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.78      0.76       760
#            1       0.62      0.59      0.60       579
#            2       0.63      0.60      0.62       341
#
#     accuracy                           0.68      1680
#    macro avg       0.67      0.66      0.66      1680
# weighted avg       0.68      0.68      0.68      1680

# %% [markdown]
# Akurasi Training 75% <br>
# Akurasi Testing 67% <br>

# %%
df_imp = mean_score_decrease(X_train, y_train, model, plot=True, topk=10)
